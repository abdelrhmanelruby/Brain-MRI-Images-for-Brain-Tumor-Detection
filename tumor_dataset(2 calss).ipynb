# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import load_img ,img_to_array
from keras.models import Sequential
from sklearn.model_selection import train_test_split
from keras.layers import Conv2D,Dropout,MaxPooling2D,Flatten,Dense,BatchNormalization
from tensorflow.keras import regularizers
import keras
import shutil
import os
from keras_vggface.vggface import VGGFace
from IPython.display import clear_output
from sklearn.metrics import accuracy_score,confusion_matrix
import seaborn as sns
from keras.callbacks import ModelCheckpoint,EarlyStopping
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.applications.resnet50 import preprocess_input
import tensorflow as tf

# %%
import tensorflow
print(tensorflow.__version__)
# Out:
# 2.9.1

# %%
x = []
y = []
datadir = r'Brain MRI Images for Brain Tumor Detection'
Categories = []
for file_label in os.listdir(datadir):
    Categories.append(file_label)
    for file_name in os.listdir(datadir+'/'+file_label):
        x.append(datadir+'/'+file_label+'/'+file_name)
        y.append(file_label)

dataset=pd.DataFrame({
        'image_path' : x,
        'label' : y
    })

# %%
train_df, test_df = train_test_split(dataset, test_size=0.2, shuffle=True, random_state=123, stratify=dataset['label'])
#test_df, valid_df = train_test_split(test_df, test_size=0.5, shuffle=True, random_state=123)

# %%
print("train_df = ",len(train_df))
#print("valid_df = ",len(valid_df))
print("test_df = ",len(test_df))
# Out:
# train_df =  202
# test_df =  51

# %%
train_datagen = ImageDataGenerator(horizontal_flip= True)

test_datagen = ImageDataGenerator()

# %%
training_set = train_datagen.flow_from_dataframe( train_df, 
                                       x_col= 'image_path', 
                                       y_col= 'label', 
                                       target_size= (224,224), 
                                       class_mode= 'categorical',
                                       color_mode= "rgb", 
                                       shuffle= True, 
                                       batch_size= 32)
# Out:
# Found 202 validated image filenames belonging to 2 classes.

# %%
vald_set = test_datagen.flow_from_dataframe( valid_df, 
                                       x_col= 'image_path', 
                                       y_col= 'label', 
                                       target_size= (224,224), 
                                       class_mode= 'categorical',
                                       color_mode= "rgb", 
                                       shuffle= True, 
                                       batch_size= 32)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 vald_set = test_datagen.flow_from_dataframe( valid_df,
#       2                                        x_col= 'image_path',
#       3                                        y_col= 'label',
#       4                                        target_size= (224,224),
#       5                                        class_mode= 'categorical',
#       6                                        color_mode= "rgb",
#       7                                        shuffle= True,
#       8                                        batch_size= 32)
#
# NameError: name 'valid_df' is not defined

# %%
test_set = test_datagen.flow_from_dataframe( test_df, 
                                      x_col= 'image_path', 
                                      y_col= 'label', 
                                      target_size= (224,224), 
                                      class_mode= 'categorical',
                                      color_mode= "rgb", 
                                      shuffle= False, 
                                      batch_size= 32)
# Out:
# Found 51 validated image filenames belonging to 2 classes.

# %%
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.compat.v1.Session(config=config)

# %%
base_model = keras.models.load_model('44class_96.5.h5')
for layer in base_model.layers:
    layer.trainable=False

# %%
base_model.pop()
base_model.pop()
base_model.pop()

# %%
base_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb5 (Functional)  (None, 2048)             28513527
#
#  batch_normalization (BatchN  (None, 2048)             8192
#  ormalization)
#
# =================================================================
# Total params: 28,521,719
# Trainable params: 0
# Non-trainable params: 28,521,719
# _________________________________________________________________

# %%
model = Sequential([
    base_model,
    BatchNormalization(axis= -1, momentum= 0.99, epsilon= 0.001),
    Dense(256, 
          kernel_regularizer= regularizers.l2(l= 0.016), 
          activity_regularizer= regularizers.l1(0.006),
          bias_regularizer= regularizers.l1(0.006), 
          activation= 'relu'),
    
    Dropout(rate= 0.45, 
            seed= 123),
    Dense(256, activation= 'relu'),
    Dense(2, activation= 'softmax')
])

# %%
""" model = Sequential()
model.add(base_model)
model.add(Dense(2, activation="softmax")) """
# Out:
# ' model = Sequential()\nmodel.add(base_model)\nmodel.add(Dense(2, activation="softmax")) '

# %%
model.compile(Adamax(learning_rate= 0.0001), loss= 'categorical_crossentropy', metrics= ['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 2048)              28521719
#
#  batch_normalization_1 (Batc  (None, 2048)             8192
#  hNormalization)
#
#  dense_3 (Dense)             (None, 256)               524544
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 256)               65792
#
#  dense_5 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 29,120,761
# Trainable params: 594,946
# Non-trainable params: 28,525,815
# _________________________________________________________________

# %%
early_stopping = EarlyStopping(monitor="val_loss", patience=10)

checkpoint_name = 'Best-val_accuracy.h5' 
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_accuracy', verbose = 1, save_best_only = True,save_weights_only=True, mode ='auto')

checkpoint_name1 = 'Best-val_loss.h5' 
checkpoint1 = ModelCheckpoint(checkpoint_name1, monitor='val_loss', verbose = 1, save_best_only = True,save_weights_only=True, mode ='auto')

# %%
res = model.fit(training_set,validation_data = test_set, epochs=300,shuffle=False,callbacks=[checkpoint,checkpoint1,early_stopping])
# Out:
# Epoch 1/300
# 7/7 [==============================] - ETA: 0s - loss: 8.8816 - accuracy: 0.5990
# Epoch 1: val_accuracy improved from -inf to 0.78431, saving model to Best-val_accuracy.h5
#
# Epoch 1: val_loss improved from inf to 8.49690, saving model to Best-val_loss.h5
# 7/7 [==============================] - 25s 2s/step - loss: 8.8816 - accuracy: 0.5990 - val_loss: 8.4969 - val_accuracy: 0.7843
# Epoch 2/300
# 7/7 [==============================] - ETA: 0s - loss: 8.7586 - accuracy: 0.6436
# Epoch 2: val_accuracy improved from 0.78431 to 0.84314, saving model to Best-val_accuracy.h5
#
# Epoch 2: val_loss improved from 8.49690 to 8.40173, saving model to Best-val_loss.h5
# 7/7 [==============================] - 4s 675ms/step - loss: 8.7586 - accuracy: 0.6436 - val_loss: 8.4017 - val_accuracy: 0.8431
# Epoch 3/300
# 7/7 [==============================] - ETA: 0s - loss: 8.5743 - accuracy: 0.7079
# Epoch 3: val_accuracy improved from 0.84314 to 0.86275, saving model to Best-val_accuracy.h5
#
# Epoch 3: val_loss improved from 8.40173 to 8.34194, saving model to Best-val_loss.h5
# 7/7 [==============================] - 7s 1s/step - loss: 8.5743 - accuracy: 0.7079 - val_loss: 8.3419 - val_accuracy: 0.8627
# Epoch 4/300
# 7/7 [==============================] - ETA: 0s - loss: 8.4947 - accuracy: 0.8069
# Epoch 4: val_accuracy did not improve from 0.86275
#
# Epoch 4: val_loss improved from 8.34194 to 8.29488, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 368ms/step - loss: 8.4947 - accuracy: 0.8069 - val_loss: 8.2949 - val_accuracy: 0.8627
# Epoch 5/300
# 7/7 [==============================] - ETA: 0s - loss: 8.5322 - accuracy: 0.7327
# Epoch 5: val_accuracy did not improve from 0.86275
#
# Epoch 5: val_loss improved from 8.29488 to 8.25700, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 374ms/step - loss: 8.5322 - accuracy: 0.7327 - val_loss: 8.2570 - val_accuracy: 0.8431
# Epoch 6/300
# 7/7 [==============================] - ETA: 0s - loss: 8.4485 - accuracy: 0.7574
# Epoch 6: val_accuracy did not improve from 0.86275
#
# Epoch 6: val_loss improved from 8.25700 to 8.22682, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 400ms/step - loss: 8.4485 - accuracy: 0.7574 - val_loss: 8.2268 - val_accuracy: 0.8431
# Epoch 7/300
# 7/7 [==============================] - ETA: 0s - loss: 8.3925 - accuracy: 0.7921
# Epoch 7: val_accuracy did not improve from 0.86275
#
# Epoch 7: val_loss improved from 8.22682 to 8.20063, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 499ms/step - loss: 8.3925 - accuracy: 0.7921 - val_loss: 8.2006 - val_accuracy: 0.8627
# Epoch 8/300
# 7/7 [==============================] - ETA: 0s - loss: 8.3147 - accuracy: 0.8267
# Epoch 8: val_accuracy did not improve from 0.86275
#
# Epoch 8: val_loss improved from 8.20063 to 8.17516, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 372ms/step - loss: 8.3147 - accuracy: 0.8267 - val_loss: 8.1752 - val_accuracy: 0.8627
# Epoch 9/300
# 7/7 [==============================] - ETA: 0s - loss: 8.2723 - accuracy: 0.8614
# Epoch 9: val_accuracy did not improve from 0.86275
#
# Epoch 9: val_loss improved from 8.17516 to 8.15110, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 513ms/step - loss: 8.2723 - accuracy: 0.8614 - val_loss: 8.1511 - val_accuracy: 0.8627
# Epoch 10/300
# 7/7 [==============================] - ETA: 0s - loss: 8.2697 - accuracy: 0.8020
# Epoch 10: val_accuracy did not improve from 0.86275
#
# Epoch 10: val_loss improved from 8.15110 to 8.12788, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 384ms/step - loss: 8.2697 - accuracy: 0.8020 - val_loss: 8.1279 - val_accuracy: 0.8627
# Epoch 11/300
# 7/7 [==============================] - ETA: 0s - loss: 8.2341 - accuracy: 0.8465
# Epoch 11: val_accuracy did not improve from 0.86275
#
# Epoch 11: val_loss improved from 8.12788 to 8.10580, saving model to Best-val_loss.h5
# 7/7 [==============================] - 2s 363ms/step - loss: 8.2341 - accuracy: 0.8465 - val_loss: 8.1058 - val_accuracy: 0.8627
# Epoch 12/300
# 7/7 [==============================] - ETA: 0s - loss: 8.2686 - accuracy: 0.8069
# Epoch 12: val_accuracy did not improve from 0.86275
#
# Epoch 12: val_loss improved from 8.10580 to 8.08554, saving model to Best-val_loss.h5
# 7/7 [==============================] - 2s 359ms/step - loss: 8.2686 - accuracy: 0.8069 - val_loss: 8.0855 - val_accuracy: 0.8627
# Epoch 13/300
# 7/7 [==============================] - ETA: 0s - loss: 8.1931 - accuracy: 0.8564
# Epoch 13: val_accuracy did not improve from 0.86275
#
# Epoch 13: val_loss improved from 8.08554 to 8.06673, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 379ms/step - loss: 8.1931 - accuracy: 0.8564 - val_loss: 8.0667 - val_accuracy: 0.8627
# Epoch 14/300
# 7/7 [==============================] - ETA: 0s - loss: 8.1706 - accuracy: 0.8416
# Epoch 14: val_accuracy did not improve from 0.86275
#
# Epoch 14: val_loss improved from 8.06673 to 8.04977, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 388ms/step - loss: 8.1706 - accuracy: 0.8416 - val_loss: 8.0498 - val_accuracy: 0.8627
# Epoch 15/300
# 7/7 [==============================] - ETA: 0s - loss: 8.1943 - accuracy: 0.8218
# Epoch 15: val_accuracy did not improve from 0.86275
#
# Epoch 15: val_loss improved from 8.04977 to 8.03182, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 380ms/step - loss: 8.1943 - accuracy: 0.8218 - val_loss: 8.0318 - val_accuracy: 0.8627
# Epoch 16/300
# 7/7 [==============================] - ETA: 0s - loss: 8.1017 - accuracy: 0.8812
# Epoch 16: val_accuracy did not improve from 0.86275
#
# Epoch 16: val_loss improved from 8.03182 to 8.01372, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 377ms/step - loss: 8.1017 - accuracy: 0.8812 - val_loss: 8.0137 - val_accuracy: 0.8627
# Epoch 17/300
# 7/7 [==============================] - ETA: 0s - loss: 8.1269 - accuracy: 0.8713
# Epoch 17: val_accuracy did not improve from 0.86275
#
# Epoch 17: val_loss improved from 8.01372 to 7.99572, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 417ms/step - loss: 8.1269 - accuracy: 0.8713 - val_loss: 7.9957 - val_accuracy: 0.8627
# Epoch 18/300
# 7/7 [==============================] - ETA: 0s - loss: 8.0616 - accuracy: 0.8515
# Epoch 18: val_accuracy did not improve from 0.86275
#
# Epoch 18: val_loss improved from 7.99572 to 7.97879, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 427ms/step - loss: 8.0616 - accuracy: 0.8515 - val_loss: 7.9788 - val_accuracy: 0.8627
# Epoch 19/300
# 7/7 [==============================] - ETA: 0s - loss: 8.0525 - accuracy: 0.8812
# Epoch 19: val_accuracy did not improve from 0.86275
#
# Epoch 19: val_loss improved from 7.97879 to 7.96275, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 384ms/step - loss: 8.0525 - accuracy: 0.8812 - val_loss: 7.9628 - val_accuracy: 0.8627
# Epoch 20/300
# 7/7 [==============================] - ETA: 0s - loss: 8.0118 - accuracy: 0.8960
# Epoch 20: val_accuracy did not improve from 0.86275
#
# Epoch 20: val_loss improved from 7.96275 to 7.94505, saving model to Best-val_loss.h5
# 7/7 [==============================] - 5s 753ms/step - loss: 8.0118 - accuracy: 0.8960 - val_loss: 7.9450 - val_accuracy: 0.8627
# Epoch 21/300
# 7/7 [==============================] - ETA: 0s - loss: 8.0012 - accuracy: 0.8713
# Epoch 21: val_accuracy did not improve from 0.86275
#
# Epoch 21: val_loss improved from 7.94505 to 7.92668, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 441ms/step - loss: 8.0012 - accuracy: 0.8713 - val_loss: 7.9267 - val_accuracy: 0.8627
# Epoch 22/300
# 7/7 [==============================] - ETA: 0s - loss: 7.9915 - accuracy: 0.8663
# Epoch 22: val_accuracy improved from 0.86275 to 0.88235, saving model to Best-val_accuracy.h5
#
# Epoch 22: val_loss improved from 7.92668 to 7.90999, saving model to Best-val_loss.h5
# 7/7 [==============================] - 6s 872ms/step - loss: 7.9915 - accuracy: 0.8663 - val_loss: 7.9100 - val_accuracy: 0.8824
# Epoch 23/300
# 7/7 [==============================] - ETA: 0s - loss: 7.9556 - accuracy: 0.8713
# Epoch 23: val_accuracy did not improve from 0.88235
#
# Epoch 23: val_loss improved from 7.90999 to 7.89317, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 386ms/step - loss: 7.9556 - accuracy: 0.8713 - val_loss: 7.8932 - val_accuracy: 0.8824
# Epoch 24/300
# 7/7 [==============================] - ETA: 0s - loss: 7.9427 - accuracy: 0.8762
# Epoch 24: val_accuracy improved from 0.88235 to 0.90196, saving model to Best-val_accuracy.h5
#
# Epoch 24: val_loss improved from 7.89317 to 7.87709, saving model to Best-val_loss.h5
# 7/7 [==============================] - 4s 663ms/step - loss: 7.9427 - accuracy: 0.8762 - val_loss: 7.8771 - val_accuracy: 0.9020
# Epoch 25/300
# 7/7 [==============================] - ETA: 0s - loss: 7.9187 - accuracy: 0.8762
# Epoch 25: val_accuracy did not improve from 0.90196
#
# Epoch 25: val_loss improved from 7.87709 to 7.86241, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 367ms/step - loss: 7.9187 - accuracy: 0.8762 - val_loss: 7.8624 - val_accuracy: 0.9020
# Epoch 26/300
# 7/7 [==============================] - ETA: 0s - loss: 7.8977 - accuracy: 0.8911
# Epoch 26: val_accuracy did not improve from 0.90196
#
# Epoch 26: val_loss improved from 7.86241 to 7.84634, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 407ms/step - loss: 7.8977 - accuracy: 0.8911 - val_loss: 7.8463 - val_accuracy: 0.9020
# Epoch 27/300
# 7/7 [==============================] - ETA: 0s - loss: 7.8991 - accuracy: 0.8812
# Epoch 27: val_accuracy did not improve from 0.90196
#
# Epoch 27: val_loss improved from 7.84634 to 7.82970, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 534ms/step - loss: 7.8991 - accuracy: 0.8812 - val_loss: 7.8297 - val_accuracy: 0.9020
# Epoch 28/300
# 7/7 [==============================] - ETA: 0s - loss: 7.8619 - accuracy: 0.9010
# Epoch 28: val_accuracy did not improve from 0.90196
#
# Epoch 28: val_loss improved from 7.82970 to 7.81382, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 368ms/step - loss: 7.8619 - accuracy: 0.9010 - val_loss: 7.8138 - val_accuracy: 0.9020
# Epoch 29/300
# 7/7 [==============================] - ETA: 0s - loss: 7.8725 - accuracy: 0.8713
# Epoch 29: val_accuracy did not improve from 0.90196
#
# Epoch 29: val_loss improved from 7.81382 to 7.79757, saving model to Best-val_loss.h5
# 7/7 [==============================] - 2s 367ms/step - loss: 7.8725 - accuracy: 0.8713 - val_loss: 7.7976 - val_accuracy: 0.9020
# Epoch 30/300
# 7/7 [==============================] - ETA: 0s - loss: 7.8501 - accuracy: 0.8861
# Epoch 30: val_accuracy improved from 0.90196 to 0.92157, saving model to Best-val_accuracy.h5
#
# Epoch 30: val_loss improved from 7.79757 to 7.78139, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 533ms/step - loss: 7.8501 - accuracy: 0.8861 - val_loss: 7.7814 - val_accuracy: 0.9216
# Epoch 31/300
# 7/7 [==============================] - ETA: 0s - loss: 7.8260 - accuracy: 0.8812
# Epoch 31: val_accuracy did not improve from 0.92157
#
# Epoch 31: val_loss improved from 7.78139 to 7.76572, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 362ms/step - loss: 7.8260 - accuracy: 0.8812 - val_loss: 7.7657 - val_accuracy: 0.9216
# Epoch 32/300
# 7/7 [==============================] - ETA: 0s - loss: 7.7976 - accuracy: 0.8911
# Epoch 32: val_accuracy did not improve from 0.92157
#
# Epoch 32: val_loss improved from 7.76572 to 7.74903, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 372ms/step - loss: 7.7976 - accuracy: 0.8911 - val_loss: 7.7490 - val_accuracy: 0.9216
# Epoch 33/300
# 7/7 [==============================] - ETA: 0s - loss: 7.7646 - accuracy: 0.9010
# Epoch 33: val_accuracy improved from 0.92157 to 0.94118, saving model to Best-val_accuracy.h5
#
# Epoch 33: val_loss improved from 7.74903 to 7.73306, saving model to Best-val_loss.h5
# 7/7 [==============================] - 4s 702ms/step - loss: 7.7646 - accuracy: 0.9010 - val_loss: 7.7331 - val_accuracy: 0.9412
# Epoch 34/300
# 7/7 [==============================] - ETA: 0s - loss: 7.7472 - accuracy: 0.8960
# Epoch 34: val_accuracy did not improve from 0.94118
#
# Epoch 34: val_loss improved from 7.73306 to 7.71673, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 396ms/step - loss: 7.7472 - accuracy: 0.8960 - val_loss: 7.7167 - val_accuracy: 0.9412
# Epoch 35/300
# 7/7 [==============================] - ETA: 0s - loss: 7.7783 - accuracy: 0.8663
# Epoch 35: val_accuracy did not improve from 0.94118
#
# Epoch 35: val_loss improved from 7.71673 to 7.70057, saving model to Best-val_loss.h5
# 7/7 [==============================] - 2s 364ms/step - loss: 7.7783 - accuracy: 0.8663 - val_loss: 7.7006 - val_accuracy: 0.9412
# Epoch 36/300
# 7/7 [==============================] - ETA: 0s - loss: 7.7118 - accuracy: 0.9109
# Epoch 36: val_accuracy did not improve from 0.94118
#
# Epoch 36: val_loss improved from 7.70057 to 7.68517, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 405ms/step - loss: 7.7118 - accuracy: 0.9109 - val_loss: 7.6852 - val_accuracy: 0.9412
# Epoch 37/300
# 7/7 [==============================] - ETA: 0s - loss: 7.6933 - accuracy: 0.8812
# Epoch 37: val_accuracy did not improve from 0.94118
#
# Epoch 37: val_loss improved from 7.68517 to 7.66934, saving model to Best-val_loss.h5
# 7/7 [==============================] - 2s 365ms/step - loss: 7.6933 - accuracy: 0.8812 - val_loss: 7.6693 - val_accuracy: 0.9412
# Epoch 38/300
# 7/7 [==============================] - ETA: 0s - loss: 7.6674 - accuracy: 0.9257
# Epoch 38: val_accuracy did not improve from 0.94118
#
# Epoch 38: val_loss improved from 7.66934 to 7.65408, saving model to Best-val_loss.h5
# 7/7 [==============================] - 4s 603ms/step - loss: 7.6674 - accuracy: 0.9257 - val_loss: 7.6541 - val_accuracy: 0.9412
# Epoch 39/300
# 7/7 [==============================] - ETA: 0s - loss: 7.6715 - accuracy: 0.9109
# Epoch 39: val_accuracy did not improve from 0.94118
#
# Epoch 39: val_loss improved from 7.65408 to 7.63699, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 379ms/step - loss: 7.6715 - accuracy: 0.9109 - val_loss: 7.6370 - val_accuracy: 0.9412
# Epoch 40/300
# 7/7 [==============================] - ETA: 0s - loss: 7.6280 - accuracy: 0.9109
# Epoch 40: val_accuracy did not improve from 0.94118
#
# Epoch 40: val_loss improved from 7.63699 to 7.62109, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 485ms/step - loss: 7.6280 - accuracy: 0.9109 - val_loss: 7.6211 - val_accuracy: 0.9412
# Epoch 41/300
# 7/7 [==============================] - ETA: 0s - loss: 7.6373 - accuracy: 0.8911
# Epoch 41: val_accuracy did not improve from 0.94118
#
# Epoch 41: val_loss improved from 7.62109 to 7.60505, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 378ms/step - loss: 7.6373 - accuracy: 0.8911 - val_loss: 7.6051 - val_accuracy: 0.9412
# Epoch 42/300
# 7/7 [==============================] - ETA: 0s - loss: 7.6372 - accuracy: 0.8911
# Epoch 42: val_accuracy did not improve from 0.94118
#
# Epoch 42: val_loss improved from 7.60505 to 7.58993, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 379ms/step - loss: 7.6372 - accuracy: 0.8911 - val_loss: 7.5899 - val_accuracy: 0.9412
# Epoch 43/300
# 7/7 [==============================] - ETA: 0s - loss: 7.6303 - accuracy: 0.9257
# Epoch 43: val_accuracy did not improve from 0.94118
#
# Epoch 43: val_loss improved from 7.58993 to 7.57461, saving model to Best-val_loss.h5
# 7/7 [==============================] - 2s 374ms/step - loss: 7.6303 - accuracy: 0.9257 - val_loss: 7.5746 - val_accuracy: 0.9412
# Epoch 44/300
# 7/7 [==============================] - ETA: 0s - loss: 7.6004 - accuracy: 0.9109
# Epoch 44: val_accuracy did not improve from 0.94118
#
# Epoch 44: val_loss improved from 7.57461 to 7.55891, saving model to Best-val_loss.h5
# 7/7 [==============================] - 4s 621ms/step - loss: 7.6004 - accuracy: 0.9109 - val_loss: 7.5589 - val_accuracy: 0.9412
# Epoch 45/300
# 7/7 [==============================] - ETA: 0s - loss: 7.5530 - accuracy: 0.9158
# Epoch 45: val_accuracy did not improve from 0.94118
#
# Epoch 45: val_loss improved from 7.55891 to 7.54275, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 361ms/step - loss: 7.5530 - accuracy: 0.9158 - val_loss: 7.5427 - val_accuracy: 0.9412
# Epoch 46/300
# 7/7 [==============================] - ETA: 0s - loss: 7.5741 - accuracy: 0.9010
# Epoch 46: val_accuracy did not improve from 0.94118
#
# Epoch 46: val_loss improved from 7.54275 to 7.52830, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 445ms/step - loss: 7.5741 - accuracy: 0.9010 - val_loss: 7.5283 - val_accuracy: 0.9412
# Epoch 47/300
# 7/7 [==============================] - ETA: 0s - loss: 7.5323 - accuracy: 0.9158
# Epoch 47: val_accuracy did not improve from 0.94118
#
# Epoch 47: val_loss improved from 7.52830 to 7.51336, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 396ms/step - loss: 7.5323 - accuracy: 0.9158 - val_loss: 7.5134 - val_accuracy: 0.9412
# Epoch 48/300
# 7/7 [==============================] - ETA: 0s - loss: 7.4901 - accuracy: 0.9208
# Epoch 48: val_accuracy did not improve from 0.94118
#
# Epoch 48: val_loss improved from 7.51336 to 7.49706, saving model to Best-val_loss.h5
# 7/7 [==============================] - 4s 616ms/step - loss: 7.4901 - accuracy: 0.9208 - val_loss: 7.4971 - val_accuracy: 0.9412
# Epoch 49/300
# 7/7 [==============================] - ETA: 0s - loss: 7.4949 - accuracy: 0.9208
# Epoch 49: val_accuracy did not improve from 0.94118
#
# Epoch 49: val_loss improved from 7.49706 to 7.48178, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 393ms/step - loss: 7.4949 - accuracy: 0.9208 - val_loss: 7.4818 - val_accuracy: 0.9412
# Epoch 50/300
# 7/7 [==============================] - ETA: 0s - loss: 7.4384 - accuracy: 0.9604
# Epoch 50: val_accuracy did not improve from 0.94118
#
# Epoch 50: val_loss improved from 7.48178 to 7.46681, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 381ms/step - loss: 7.4384 - accuracy: 0.9604 - val_loss: 7.4668 - val_accuracy: 0.9412
# Epoch 51/300
# 7/7 [==============================] - ETA: 0s - loss: 7.4536 - accuracy: 0.9208
# Epoch 51: val_accuracy did not improve from 0.94118
#
# Epoch 51: val_loss improved from 7.46681 to 7.45220, saving model to Best-val_loss.h5
# 7/7 [==============================] - 4s 561ms/step - loss: 7.4536 - accuracy: 0.9208 - val_loss: 7.4522 - val_accuracy: 0.9412
# Epoch 52/300
# 7/7 [==============================] - ETA: 0s - loss: 7.4981 - accuracy: 0.9059
# Epoch 52: val_accuracy did not improve from 0.94118
#
# Epoch 52: val_loss improved from 7.45220 to 7.43731, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 354ms/step - loss: 7.4981 - accuracy: 0.9059 - val_loss: 7.4373 - val_accuracy: 0.9412
# Epoch 53/300
# 7/7 [==============================] - ETA: 0s - loss: 7.4062 - accuracy: 0.9554
# Epoch 53: val_accuracy did not improve from 0.94118
#
# Epoch 53: val_loss improved from 7.43731 to 7.42170, saving model to Best-val_loss.h5
# 7/7 [==============================] - 4s 564ms/step - loss: 7.4062 - accuracy: 0.9554 - val_loss: 7.4217 - val_accuracy: 0.9412
# Epoch 54/300
# 7/7 [==============================] - ETA: 0s - loss: 7.4172 - accuracy: 0.9307
# Epoch 54: val_accuracy did not improve from 0.94118
#
# Epoch 54: val_loss improved from 7.42170 to 7.40656, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 412ms/step - loss: 7.4172 - accuracy: 0.9307 - val_loss: 7.4066 - val_accuracy: 0.9412
# Epoch 55/300
# 7/7 [==============================] - ETA: 0s - loss: 7.3881 - accuracy: 0.9505
# Epoch 55: val_accuracy did not improve from 0.94118
#
# Epoch 55: val_loss improved from 7.40656 to 7.39016, saving model to Best-val_loss.h5
# 7/7 [==============================] - 2s 368ms/step - loss: 7.3881 - accuracy: 0.9505 - val_loss: 7.3902 - val_accuracy: 0.9412
# Epoch 56/300
# 7/7 [==============================] - ETA: 0s - loss: 7.3778 - accuracy: 0.9307
# Epoch 56: val_accuracy did not improve from 0.94118
#
# Epoch 56: val_loss improved from 7.39016 to 7.37497, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 407ms/step - loss: 7.3778 - accuracy: 0.9307 - val_loss: 7.3750 - val_accuracy: 0.9412
# Epoch 57/300
# 7/7 [==============================] - ETA: 0s - loss: 7.3339 - accuracy: 0.9554
# Epoch 57: val_accuracy did not improve from 0.94118
#
# Epoch 57: val_loss improved from 7.37497 to 7.35881, saving model to Best-val_loss.h5
# 7/7 [==============================] - 4s 662ms/step - loss: 7.3339 - accuracy: 0.9554 - val_loss: 7.3588 - val_accuracy: 0.9412
# Epoch 58/300
# 7/7 [==============================] - ETA: 0s - loss: 7.3916 - accuracy: 0.9059
# Epoch 58: val_accuracy did not improve from 0.94118
#
# Epoch 58: val_loss improved from 7.35881 to 7.34274, saving model to Best-val_loss.h5
# 7/7 [==============================] - 4s 541ms/step - loss: 7.3916 - accuracy: 0.9059 - val_loss: 7.3427 - val_accuracy: 0.9412
# Epoch 59/300
# 7/7 [==============================] - ETA: 0s - loss: 7.3597 - accuracy: 0.9158
# Epoch 59: val_accuracy did not improve from 0.94118
#
# Epoch 59: val_loss improved from 7.34274 to 7.32775, saving model to Best-val_loss.h5
# 7/7 [==============================] - 5s 694ms/step - loss: 7.3597 - accuracy: 0.9158 - val_loss: 7.3277 - val_accuracy: 0.9412
# Epoch 60/300
# 7/7 [==============================] - ETA: 0s - loss: 7.3290 - accuracy: 0.9356
# Epoch 60: val_accuracy did not improve from 0.94118
#
# Epoch 60: val_loss improved from 7.32775 to 7.31514, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 366ms/step - loss: 7.3290 - accuracy: 0.9356 - val_loss: 7.3151 - val_accuracy: 0.9412
# Epoch 61/300
# 7/7 [==============================] - ETA: 0s - loss: 7.3178 - accuracy: 0.9208
# Epoch 61: val_accuracy did not improve from 0.94118
#
# Epoch 61: val_loss improved from 7.31514 to 7.30047, saving model to Best-val_loss.h5
# 7/7 [==============================] - 4s 695ms/step - loss: 7.3178 - accuracy: 0.9208 - val_loss: 7.3005 - val_accuracy: 0.9412
# Epoch 62/300
# 7/7 [==============================] - ETA: 0s - loss: 7.3210 - accuracy: 0.9109
# Epoch 62: val_accuracy did not improve from 0.94118
#
# Epoch 62: val_loss improved from 7.30047 to 7.28740, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 363ms/step - loss: 7.3210 - accuracy: 0.9109 - val_loss: 7.2874 - val_accuracy: 0.9412
# Epoch 63/300
# 7/7 [==============================] - ETA: 0s - loss: 7.2944 - accuracy: 0.9208
# Epoch 63: val_accuracy did not improve from 0.94118
#
# Epoch 63: val_loss improved from 7.28740 to 7.27220, saving model to Best-val_loss.h5
# 7/7 [==============================] - 4s 549ms/step - loss: 7.2944 - accuracy: 0.9208 - val_loss: 7.2722 - val_accuracy: 0.9412
# Epoch 64/300
# 7/7 [==============================] - ETA: 0s - loss: 7.2811 - accuracy: 0.9109
# Epoch 64: val_accuracy improved from 0.94118 to 0.96078, saving model to Best-val_accuracy.h5
#
# Epoch 64: val_loss improved from 7.27220 to 7.25847, saving model to Best-val_loss.h5
# 7/7 [==============================] - 6s 874ms/step - loss: 7.2811 - accuracy: 0.9109 - val_loss: 7.2585 - val_accuracy: 0.9608
# Epoch 65/300
# 7/7 [==============================] - ETA: 0s - loss: 7.2526 - accuracy: 0.9406
# Epoch 65: val_accuracy did not improve from 0.96078
#
# Epoch 65: val_loss improved from 7.25847 to 7.24382, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 401ms/step - loss: 7.2526 - accuracy: 0.9406 - val_loss: 7.2438 - val_accuracy: 0.9608
# Epoch 66/300
# 7/7 [==============================] - ETA: 0s - loss: 7.2014 - accuracy: 0.9406
# Epoch 66: val_accuracy did not improve from 0.96078
#
# Epoch 66: val_loss improved from 7.24382 to 7.22868, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 366ms/step - loss: 7.2014 - accuracy: 0.9406 - val_loss: 7.2287 - val_accuracy: 0.9608
# Epoch 67/300
# 7/7 [==============================] - ETA: 0s - loss: 7.2235 - accuracy: 0.9257
# Epoch 67: val_accuracy did not improve from 0.96078
#
# Epoch 67: val_loss improved from 7.22868 to 7.21368, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 420ms/step - loss: 7.2235 - accuracy: 0.9257 - val_loss: 7.2137 - val_accuracy: 0.9608
# Epoch 68/300
# 7/7 [==============================] - ETA: 0s - loss: 7.2186 - accuracy: 0.9059
# Epoch 68: val_accuracy did not improve from 0.96078
#
# Epoch 68: val_loss improved from 7.21368 to 7.19913, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 390ms/step - loss: 7.2186 - accuracy: 0.9059 - val_loss: 7.1991 - val_accuracy: 0.9412
# Epoch 69/300
# 7/7 [==============================] - ETA: 0s - loss: 7.1764 - accuracy: 0.9554
# Epoch 69: val_accuracy did not improve from 0.96078
#
# Epoch 69: val_loss improved from 7.19913 to 7.18441, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 519ms/step - loss: 7.1764 - accuracy: 0.9554 - val_loss: 7.1844 - val_accuracy: 0.9412
# Epoch 70/300
# 7/7 [==============================] - ETA: 0s - loss: 7.1465 - accuracy: 0.9356
# Epoch 70: val_accuracy did not improve from 0.96078
#
# Epoch 70: val_loss improved from 7.18441 to 7.16997, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 383ms/step - loss: 7.1465 - accuracy: 0.9356 - val_loss: 7.1700 - val_accuracy: 0.9412
# Epoch 71/300
# 7/7 [==============================] - ETA: 0s - loss: 7.1361 - accuracy: 0.9604
# Epoch 71: val_accuracy did not improve from 0.96078
#
# Epoch 71: val_loss improved from 7.16997 to 7.15519, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 500ms/step - loss: 7.1361 - accuracy: 0.9604 - val_loss: 7.1552 - val_accuracy: 0.9412
# Epoch 72/300
# 7/7 [==============================] - ETA: 0s - loss: 7.1304 - accuracy: 0.9406
# Epoch 72: val_accuracy did not improve from 0.96078
#
# Epoch 72: val_loss improved from 7.15519 to 7.14012, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 383ms/step - loss: 7.1304 - accuracy: 0.9406 - val_loss: 7.1401 - val_accuracy: 0.9412
# Epoch 73/300
# 7/7 [==============================] - ETA: 0s - loss: 7.1413 - accuracy: 0.9307
# Epoch 73: val_accuracy did not improve from 0.96078
#
# Epoch 73: val_loss improved from 7.14012 to 7.12464, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 523ms/step - loss: 7.1413 - accuracy: 0.9307 - val_loss: 7.1246 - val_accuracy: 0.9412
# Epoch 74/300
# 7/7 [==============================] - ETA: 0s - loss: 7.1125 - accuracy: 0.9505
# Epoch 74: val_accuracy did not improve from 0.96078
#
# Epoch 74: val_loss improved from 7.12464 to 7.10945, saving model to Best-val_loss.h5
# 7/7 [==============================] - 2s 366ms/step - loss: 7.1125 - accuracy: 0.9505 - val_loss: 7.1094 - val_accuracy: 0.9412
# Epoch 75/300
# 7/7 [==============================] - ETA: 0s - loss: 7.0670 - accuracy: 0.9554
# Epoch 75: val_accuracy did not improve from 0.96078
#
# Epoch 75: val_loss improved from 7.10945 to 7.09492, saving model to Best-val_loss.h5
# 7/7 [==============================] - 2s 371ms/step - loss: 7.0670 - accuracy: 0.9554 - val_loss: 7.0949 - val_accuracy: 0.9608
# Epoch 76/300
# 7/7 [==============================] - ETA: 0s - loss: 7.0543 - accuracy: 0.9455
# Epoch 76: val_accuracy did not improve from 0.96078
#
# Epoch 76: val_loss improved from 7.09492 to 7.08013, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 403ms/step - loss: 7.0543 - accuracy: 0.9455 - val_loss: 7.0801 - val_accuracy: 0.9608
# Epoch 77/300
# 7/7 [==============================] - ETA: 0s - loss: 7.1008 - accuracy: 0.8960
# Epoch 77: val_accuracy did not improve from 0.96078
#
# Epoch 77: val_loss improved from 7.08013 to 7.06600, saving model to Best-val_loss.h5
# 7/7 [==============================] - 4s 574ms/step - loss: 7.1008 - accuracy: 0.8960 - val_loss: 7.0660 - val_accuracy: 0.9216
# Epoch 78/300
# 7/7 [==============================] - ETA: 0s - loss: 7.1141 - accuracy: 0.9109
# Epoch 78: val_accuracy did not improve from 0.96078
#
# Epoch 78: val_loss improved from 7.06600 to 7.05220, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 391ms/step - loss: 7.1141 - accuracy: 0.9109 - val_loss: 7.0522 - val_accuracy: 0.9608
# Epoch 79/300
# 7/7 [==============================] - ETA: 0s - loss: 7.0136 - accuracy: 0.9653
# Epoch 79: val_accuracy did not improve from 0.96078
#
# Epoch 79: val_loss improved from 7.05220 to 7.03885, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 401ms/step - loss: 7.0136 - accuracy: 0.9653 - val_loss: 7.0389 - val_accuracy: 0.9608
# Epoch 80/300
# 7/7 [==============================] - ETA: 0s - loss: 7.0030 - accuracy: 0.9455
# Epoch 80: val_accuracy did not improve from 0.96078
#
# Epoch 80: val_loss improved from 7.03885 to 7.02470, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 432ms/step - loss: 7.0030 - accuracy: 0.9455 - val_loss: 7.0247 - val_accuracy: 0.9608
# Epoch 81/300
# 7/7 [==============================] - ETA: 0s - loss: 7.0083 - accuracy: 0.9356
# Epoch 81: val_accuracy did not improve from 0.96078
#
# Epoch 81: val_loss improved from 7.02470 to 7.01066, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 392ms/step - loss: 7.0083 - accuracy: 0.9356 - val_loss: 7.0107 - val_accuracy: 0.9412
# Epoch 82/300
# 7/7 [==============================] - ETA: 0s - loss: 6.9801 - accuracy: 0.9505
# Epoch 82: val_accuracy did not improve from 0.96078
#
# Epoch 82: val_loss improved from 7.01066 to 6.99693, saving model to Best-val_loss.h5
# 7/7 [==============================] - 4s 584ms/step - loss: 6.9801 - accuracy: 0.9505 - val_loss: 6.9969 - val_accuracy: 0.9216
# Epoch 83/300
# 7/7 [==============================] - ETA: 0s - loss: 6.9606 - accuracy: 0.9604
# Epoch 83: val_accuracy did not improve from 0.96078
#
# Epoch 83: val_loss improved from 6.99693 to 6.98204, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 368ms/step - loss: 6.9606 - accuracy: 0.9604 - val_loss: 6.9820 - val_accuracy: 0.9412
# Epoch 84/300
# 7/7 [==============================] - ETA: 0s - loss: 6.9444 - accuracy: 0.9554
# Epoch 84: val_accuracy did not improve from 0.96078
#
# Epoch 84: val_loss improved from 6.98204 to 6.96717, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 400ms/step - loss: 6.9444 - accuracy: 0.9554 - val_loss: 6.9672 - val_accuracy: 0.9412
# Epoch 85/300
# 7/7 [==============================] - ETA: 0s - loss: 6.9408 - accuracy: 0.9554
# Epoch 85: val_accuracy did not improve from 0.96078
#
# Epoch 85: val_loss improved from 6.96717 to 6.95216, saving model to Best-val_loss.h5
# 7/7 [==============================] - 2s 365ms/step - loss: 6.9408 - accuracy: 0.9554 - val_loss: 6.9522 - val_accuracy: 0.9412
# Epoch 86/300
# 7/7 [==============================] - ETA: 0s - loss: 6.9154 - accuracy: 0.9604
# Epoch 86: val_accuracy did not improve from 0.96078
#
# Epoch 86: val_loss improved from 6.95216 to 6.93774, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 420ms/step - loss: 6.9154 - accuracy: 0.9604 - val_loss: 6.9377 - val_accuracy: 0.9216
# Epoch 87/300
# 7/7 [==============================] - ETA: 0s - loss: 6.9059 - accuracy: 0.9554
# Epoch 87: val_accuracy did not improve from 0.96078
#
# Epoch 87: val_loss improved from 6.93774 to 6.92398, saving model to Best-val_loss.h5
# 7/7 [==============================] - 2s 358ms/step - loss: 6.9059 - accuracy: 0.9554 - val_loss: 6.9240 - val_accuracy: 0.9216
# Epoch 88/300
# 7/7 [==============================] - ETA: 0s - loss: 6.8995 - accuracy: 0.9455
# Epoch 88: val_accuracy did not improve from 0.96078
#
# Epoch 88: val_loss improved from 6.92398 to 6.90983, saving model to Best-val_loss.h5
# 7/7 [==============================] - 4s 679ms/step - loss: 6.8995 - accuracy: 0.9455 - val_loss: 6.9098 - val_accuracy: 0.9216
# Epoch 89/300
# 7/7 [==============================] - ETA: 0s - loss: 6.8650 - accuracy: 0.9604
# Epoch 89: val_accuracy did not improve from 0.96078
#
# Epoch 89: val_loss improved from 6.90983 to 6.89567, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 375ms/step - loss: 6.8650 - accuracy: 0.9604 - val_loss: 6.8957 - val_accuracy: 0.9412
# Epoch 90/300
# 7/7 [==============================] - ETA: 0s - loss: 6.8526 - accuracy: 0.9604
# Epoch 90: val_accuracy did not improve from 0.96078
#
# Epoch 90: val_loss improved from 6.89567 to 6.88130, saving model to Best-val_loss.h5
# 7/7 [==============================] - 2s 362ms/step - loss: 6.8526 - accuracy: 0.9604 - val_loss: 6.8813 - val_accuracy: 0.9608
# Epoch 91/300
# 7/7 [==============================] - ETA: 0s - loss: 6.8391 - accuracy: 0.9554
# Epoch 91: val_accuracy did not improve from 0.96078
#
# Epoch 91: val_loss improved from 6.88130 to 6.86714, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 376ms/step - loss: 6.8391 - accuracy: 0.9554 - val_loss: 6.8671 - val_accuracy: 0.9608
# Epoch 92/300
# 7/7 [==============================] - ETA: 0s - loss: 6.8370 - accuracy: 0.9604
# Epoch 92: val_accuracy did not improve from 0.96078
#
# Epoch 92: val_loss improved from 6.86714 to 6.85310, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 400ms/step - loss: 6.8370 - accuracy: 0.9604 - val_loss: 6.8531 - val_accuracy: 0.9608
# Epoch 93/300
# 7/7 [==============================] - ETA: 0s - loss: 6.8356 - accuracy: 0.9505
# Epoch 93: val_accuracy did not improve from 0.96078
#
# Epoch 93: val_loss improved from 6.85310 to 6.83840, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 511ms/step - loss: 6.8356 - accuracy: 0.9505 - val_loss: 6.8384 - val_accuracy: 0.9412
# Epoch 94/300
# 7/7 [==============================] - ETA: 0s - loss: 6.7936 - accuracy: 0.9703
# Epoch 94: val_accuracy did not improve from 0.96078
#
# Epoch 94: val_loss improved from 6.83840 to 6.82428, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 387ms/step - loss: 6.7936 - accuracy: 0.9703 - val_loss: 6.8243 - val_accuracy: 0.9608
# Epoch 95/300
# 7/7 [==============================] - ETA: 0s - loss: 6.7890 - accuracy: 0.9554
# Epoch 95: val_accuracy did not improve from 0.96078
#
# Epoch 95: val_loss improved from 6.82428 to 6.80986, saving model to Best-val_loss.h5
# 7/7 [==============================] - 2s 367ms/step - loss: 6.7890 - accuracy: 0.9554 - val_loss: 6.8099 - val_accuracy: 0.9608
# Epoch 96/300
# 7/7 [==============================] - ETA: 0s - loss: 6.7819 - accuracy: 0.9604
# Epoch 96: val_accuracy did not improve from 0.96078
#
# Epoch 96: val_loss improved from 6.80986 to 6.79533, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 415ms/step - loss: 6.7819 - accuracy: 0.9604 - val_loss: 6.7953 - val_accuracy: 0.9608
# Epoch 97/300
# 7/7 [==============================] - ETA: 0s - loss: 6.7537 - accuracy: 0.9554
# Epoch 97: val_accuracy did not improve from 0.96078
#
# Epoch 97: val_loss improved from 6.79533 to 6.78086, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 414ms/step - loss: 6.7537 - accuracy: 0.9554 - val_loss: 6.7809 - val_accuracy: 0.9608
# Epoch 98/300
# 7/7 [==============================] - ETA: 0s - loss: 6.7344 - accuracy: 0.9703
# Epoch 98: val_accuracy did not improve from 0.96078
#
# Epoch 98: val_loss improved from 6.78086 to 6.76638, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 472ms/step - loss: 6.7344 - accuracy: 0.9703 - val_loss: 6.7664 - val_accuracy: 0.9608
# Epoch 99/300
# 7/7 [==============================] - ETA: 0s - loss: 6.7519 - accuracy: 0.9406
# Epoch 99: val_accuracy improved from 0.96078 to 0.98039, saving model to Best-val_accuracy.h5
#
# Epoch 99: val_loss improved from 6.76638 to 6.75202, saving model to Best-val_loss.h5
# 7/7 [==============================] - 4s 688ms/step - loss: 6.7519 - accuracy: 0.9406 - val_loss: 6.7520 - val_accuracy: 0.9804
# Epoch 100/300
# 7/7 [==============================] - ETA: 0s - loss: 6.7152 - accuracy: 0.9554
# Epoch 100: val_accuracy did not improve from 0.98039
#
# Epoch 100: val_loss improved from 6.75202 to 6.73857, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 408ms/step - loss: 6.7152 - accuracy: 0.9554 - val_loss: 6.7386 - val_accuracy: 0.9804
# Epoch 101/300
# 7/7 [==============================] - ETA: 0s - loss: 6.7004 - accuracy: 0.9554
# Epoch 101: val_accuracy did not improve from 0.98039
#
# Epoch 101: val_loss improved from 6.73857 to 6.72513, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 408ms/step - loss: 6.7004 - accuracy: 0.9554 - val_loss: 6.7251 - val_accuracy: 0.9804
# Epoch 102/300
# 7/7 [==============================] - ETA: 0s - loss: 6.6977 - accuracy: 0.9455
# Epoch 102: val_accuracy did not improve from 0.98039
#
# Epoch 102: val_loss improved from 6.72513 to 6.71173, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 382ms/step - loss: 6.6977 - accuracy: 0.9455 - val_loss: 6.7117 - val_accuracy: 0.9804
# Epoch 103/300
# 7/7 [==============================] - ETA: 0s - loss: 6.7012 - accuracy: 0.9554
# Epoch 103: val_accuracy did not improve from 0.98039
#
# Epoch 103: val_loss improved from 6.71173 to 6.69768, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 378ms/step - loss: 6.7012 - accuracy: 0.9554 - val_loss: 6.6977 - val_accuracy: 0.9804
# Epoch 104/300
# 7/7 [==============================] - ETA: 0s - loss: 6.6680 - accuracy: 0.9604
# Epoch 104: val_accuracy did not improve from 0.98039
#
# Epoch 104: val_loss improved from 6.69768 to 6.68456, saving model to Best-val_loss.h5
# 7/7 [==============================] - 6s 892ms/step - loss: 6.6680 - accuracy: 0.9604 - val_loss: 6.6846 - val_accuracy: 0.9804
# Epoch 105/300
# 7/7 [==============================] - ETA: 0s - loss: 6.6610 - accuracy: 0.9505
# Epoch 105: val_accuracy did not improve from 0.98039
#
# Epoch 105: val_loss improved from 6.68456 to 6.67092, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 419ms/step - loss: 6.6610 - accuracy: 0.9505 - val_loss: 6.6709 - val_accuracy: 0.9804
# Epoch 106/300
# 7/7 [==============================] - ETA: 0s - loss: 6.6084 - accuracy: 0.9653
# Epoch 106: val_accuracy did not improve from 0.98039
#
# Epoch 106: val_loss improved from 6.67092 to 6.65784, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 401ms/step - loss: 6.6084 - accuracy: 0.9653 - val_loss: 6.6578 - val_accuracy: 0.9804
# Epoch 107/300
# 7/7 [==============================] - ETA: 0s - loss: 6.6316 - accuracy: 0.9455
# Epoch 107: val_accuracy did not improve from 0.98039
#
# Epoch 107: val_loss improved from 6.65784 to 6.64485, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 501ms/step - loss: 6.6316 - accuracy: 0.9455 - val_loss: 6.6448 - val_accuracy: 0.9804
# Epoch 108/300
# 7/7 [==============================] - ETA: 0s - loss: 6.6115 - accuracy: 0.9554
# Epoch 108: val_accuracy did not improve from 0.98039
#
# Epoch 108: val_loss improved from 6.64485 to 6.63185, saving model to Best-val_loss.h5
# 7/7 [==============================] - 2s 365ms/step - loss: 6.6115 - accuracy: 0.9554 - val_loss: 6.6318 - val_accuracy: 0.9804
# Epoch 109/300
# 7/7 [==============================] - ETA: 0s - loss: 6.5988 - accuracy: 0.9653
# Epoch 109: val_accuracy did not improve from 0.98039
#
# Epoch 109: val_loss improved from 6.63185 to 6.61855, saving model to Best-val_loss.h5
# 7/7 [==============================] - 4s 553ms/step - loss: 6.5988 - accuracy: 0.9653 - val_loss: 6.6185 - val_accuracy: 0.9804
# Epoch 110/300
# 7/7 [==============================] - ETA: 0s - loss: 6.5872 - accuracy: 0.9554
# Epoch 110: val_accuracy did not improve from 0.98039
#
# Epoch 110: val_loss improved from 6.61855 to 6.60494, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 471ms/step - loss: 6.5872 - accuracy: 0.9554 - val_loss: 6.6049 - val_accuracy: 0.9804
# Epoch 111/300
# 7/7 [==============================] - ETA: 0s - loss: 6.5759 - accuracy: 0.9554
# Epoch 111: val_accuracy did not improve from 0.98039
#
# Epoch 111: val_loss improved from 6.60494 to 6.59108, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 383ms/step - loss: 6.5759 - accuracy: 0.9554 - val_loss: 6.5911 - val_accuracy: 0.9804
# Epoch 112/300
# 7/7 [==============================] - ETA: 0s - loss: 6.5315 - accuracy: 0.9851
# Epoch 112: val_accuracy did not improve from 0.98039
#
# Epoch 112: val_loss improved from 6.59108 to 6.57667, saving model to Best-val_loss.h5
# 7/7 [==============================] - 2s 366ms/step - loss: 6.5315 - accuracy: 0.9851 - val_loss: 6.5767 - val_accuracy: 0.9804
# Epoch 113/300
# 7/7 [==============================] - ETA: 0s - loss: 6.5517 - accuracy: 0.9653
# Epoch 113: val_accuracy did not improve from 0.98039
#
# Epoch 113: val_loss improved from 6.57667 to 6.56145, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 405ms/step - loss: 6.5517 - accuracy: 0.9653 - val_loss: 6.5615 - val_accuracy: 0.9804
# Epoch 114/300
# 7/7 [==============================] - ETA: 0s - loss: 6.5120 - accuracy: 0.9752
# Epoch 114: val_accuracy did not improve from 0.98039
#
# Epoch 114: val_loss improved from 6.56145 to 6.54741, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 460ms/step - loss: 6.5120 - accuracy: 0.9752 - val_loss: 6.5474 - val_accuracy: 0.9804
# Epoch 115/300
# 7/7 [==============================] - ETA: 0s - loss: 6.5270 - accuracy: 0.9653
# Epoch 115: val_accuracy did not improve from 0.98039
#
# Epoch 115: val_loss improved from 6.54741 to 6.53508, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 392ms/step - loss: 6.5270 - accuracy: 0.9653 - val_loss: 6.5351 - val_accuracy: 0.9804
# Epoch 116/300
# 7/7 [==============================] - ETA: 0s - loss: 6.4833 - accuracy: 0.9752
# Epoch 116: val_accuracy did not improve from 0.98039
#
# Epoch 116: val_loss improved from 6.53508 to 6.52193, saving model to Best-val_loss.h5
# 7/7 [==============================] - 2s 366ms/step - loss: 6.4833 - accuracy: 0.9752 - val_loss: 6.5219 - val_accuracy: 0.9804
# Epoch 117/300
# 7/7 [==============================] - ETA: 0s - loss: 6.4636 - accuracy: 0.9752
# Epoch 117: val_accuracy did not improve from 0.98039
#
# Epoch 117: val_loss improved from 6.52193 to 6.50824, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 419ms/step - loss: 6.4636 - accuracy: 0.9752 - val_loss: 6.5082 - val_accuracy: 0.9804
# Epoch 118/300
# 7/7 [==============================] - ETA: 0s - loss: 6.4396 - accuracy: 0.9851
# Epoch 118: val_accuracy did not improve from 0.98039
#
# Epoch 118: val_loss improved from 6.50824 to 6.49513, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 504ms/step - loss: 6.4396 - accuracy: 0.9851 - val_loss: 6.4951 - val_accuracy: 0.9804
# Epoch 119/300
# 7/7 [==============================] - ETA: 0s - loss: 6.4517 - accuracy: 0.9703
# Epoch 119: val_accuracy did not improve from 0.98039
#
# Epoch 119: val_loss improved from 6.49513 to 6.48203, saving model to Best-val_loss.h5
# 7/7 [==============================] - 2s 364ms/step - loss: 6.4517 - accuracy: 0.9703 - val_loss: 6.4820 - val_accuracy: 0.9804
# Epoch 120/300
# 7/7 [==============================] - ETA: 0s - loss: 6.4525 - accuracy: 0.9604
# Epoch 120: val_accuracy did not improve from 0.98039
#
# Epoch 120: val_loss improved from 6.48203 to 6.46862, saving model to Best-val_loss.h5
# 7/7 [==============================] - 4s 599ms/step - loss: 6.4525 - accuracy: 0.9604 - val_loss: 6.4686 - val_accuracy: 0.9804
# Epoch 121/300
# 7/7 [==============================] - ETA: 0s - loss: 6.4348 - accuracy: 0.9653
# Epoch 121: val_accuracy did not improve from 0.98039
#
# Epoch 121: val_loss improved from 6.46862 to 6.45381, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 381ms/step - loss: 6.4348 - accuracy: 0.9653 - val_loss: 6.4538 - val_accuracy: 0.9804
# Epoch 122/300
# 7/7 [==============================] - ETA: 0s - loss: 6.3916 - accuracy: 0.9851
# Epoch 122: val_accuracy did not improve from 0.98039
#
# Epoch 122: val_loss improved from 6.45381 to 6.43951, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 401ms/step - loss: 6.3916 - accuracy: 0.9851 - val_loss: 6.4395 - val_accuracy: 0.9804
# Epoch 123/300
# 7/7 [==============================] - ETA: 0s - loss: 6.4044 - accuracy: 0.9604
# Epoch 123: val_accuracy did not improve from 0.98039
#
# Epoch 123: val_loss improved from 6.43951 to 6.42582, saving model to Best-val_loss.h5
# 7/7 [==============================] - 2s 369ms/step - loss: 6.4044 - accuracy: 0.9604 - val_loss: 6.4258 - val_accuracy: 0.9804
# Epoch 124/300
# 7/7 [==============================] - ETA: 0s - loss: 6.3829 - accuracy: 0.9752
# Epoch 124: val_accuracy did not improve from 0.98039
#
# Epoch 124: val_loss improved from 6.42582 to 6.41232, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 396ms/step - loss: 6.3829 - accuracy: 0.9752 - val_loss: 6.4123 - val_accuracy: 0.9804
# Epoch 125/300
# 7/7 [==============================] - ETA: 0s - loss: 6.3508 - accuracy: 0.9752
# Epoch 125: val_accuracy did not improve from 0.98039
#
# Epoch 125: val_loss improved from 6.41232 to 6.39898, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 416ms/step - loss: 6.3508 - accuracy: 0.9752 - val_loss: 6.3990 - val_accuracy: 0.9804
# Epoch 126/300
# 7/7 [==============================] - ETA: 0s - loss: 6.3586 - accuracy: 0.9554
# Epoch 126: val_accuracy did not improve from 0.98039
#
# Epoch 126: val_loss improved from 6.39898 to 6.38552, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 433ms/step - loss: 6.3586 - accuracy: 0.9554 - val_loss: 6.3855 - val_accuracy: 0.9804
# Epoch 127/300
# 7/7 [==============================] - ETA: 0s - loss: 6.3091 - accuracy: 0.9851
# Epoch 127: val_accuracy did not improve from 0.98039
#
# Epoch 127: val_loss improved from 6.38552 to 6.37266, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 369ms/step - loss: 6.3091 - accuracy: 0.9851 - val_loss: 6.3727 - val_accuracy: 0.9804
# Epoch 128/300
# 7/7 [==============================] - ETA: 0s - loss: 6.3338 - accuracy: 0.9604
# Epoch 128: val_accuracy did not improve from 0.98039
#
# Epoch 128: val_loss improved from 6.37266 to 6.35969, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 397ms/step - loss: 6.3338 - accuracy: 0.9604 - val_loss: 6.3597 - val_accuracy: 0.9804
# Epoch 129/300
# 7/7 [==============================] - ETA: 0s - loss: 6.2938 - accuracy: 0.9802
# Epoch 129: val_accuracy did not improve from 0.98039
#
# Epoch 129: val_loss improved from 6.35969 to 6.34604, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 388ms/step - loss: 6.2938 - accuracy: 0.9802 - val_loss: 6.3460 - val_accuracy: 0.9804
# Epoch 130/300
# 7/7 [==============================] - ETA: 0s - loss: 6.3217 - accuracy: 0.9554
# Epoch 130: val_accuracy did not improve from 0.98039
#
# Epoch 130: val_loss improved from 6.34604 to 6.33272, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 407ms/step - loss: 6.3217 - accuracy: 0.9554 - val_loss: 6.3327 - val_accuracy: 0.9804
# Epoch 131/300
# 7/7 [==============================] - ETA: 0s - loss: 6.2952 - accuracy: 0.9703
# Epoch 131: val_accuracy did not improve from 0.98039
#
# Epoch 131: val_loss improved from 6.33272 to 6.31901, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 398ms/step - loss: 6.2952 - accuracy: 0.9703 - val_loss: 6.3190 - val_accuracy: 0.9804
# Epoch 132/300
# 7/7 [==============================] - ETA: 0s - loss: 6.2700 - accuracy: 0.9752
# ...
# Epoch 257: val_accuracy did not improve from 0.98039
#
# Epoch 257: val_loss improved from 4.75903 to 4.74794, saving model to Best-val_loss.h5
# 7/7 [==============================] - 4s 635ms/step - loss: 4.6798 - accuracy: 0.9950 - val_loss: 4.7479 - val_accuracy: 0.9608
# Epoch 258/300
# 7/7 [==============================] - ETA: 0s - loss: 4.6712 - accuracy: 0.9851
# Epoch 258: val_accuracy did not improve from 0.98039
#
# Epoch 258: val_loss improved from 4.74794 to 4.73703, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 400ms/step - loss: 4.6712 - accuracy: 0.9851 - val_loss: 4.7370 - val_accuracy: 0.9608
# Epoch 259/300
# 7/7 [==============================] - ETA: 0s - loss: 4.6618 - accuracy: 0.9851
# Epoch 259: val_accuracy did not improve from 0.98039
#
# Epoch 259: val_loss improved from 4.73703 to 4.72666, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 392ms/step - loss: 4.6618 - accuracy: 0.9851 - val_loss: 4.7267 - val_accuracy: 0.9608
# Epoch 260/300
# 7/7 [==============================] - ETA: 0s - loss: 4.6405 - accuracy: 0.9901
# Epoch 260: val_accuracy did not improve from 0.98039
#
# Epoch 260: val_loss improved from 4.72666 to 4.71570, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 408ms/step - loss: 4.6405 - accuracy: 0.9901 - val_loss: 4.7157 - val_accuracy: 0.9608
# Epoch 261/300
# 7/7 [==============================] - ETA: 0s - loss: 4.6373 - accuracy: 0.9950
# Epoch 261: val_accuracy did not improve from 0.98039
#
# Epoch 261: val_loss improved from 4.71570 to 4.70418, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 391ms/step - loss: 4.6373 - accuracy: 0.9950 - val_loss: 4.7042 - val_accuracy: 0.9608
# Epoch 262/300
# 7/7 [==============================] - ETA: 0s - loss: 4.6178 - accuracy: 0.9851
# Epoch 262: val_accuracy did not improve from 0.98039
#
# Epoch 262: val_loss improved from 4.70418 to 4.69261, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 402ms/step - loss: 4.6178 - accuracy: 0.9851 - val_loss: 4.6926 - val_accuracy: 0.9608
# Epoch 263/300
# 7/7 [==============================] - ETA: 0s - loss: 4.6048 - accuracy: 1.0000
# Epoch 263: val_accuracy did not improve from 0.98039
#
# Epoch 263: val_loss improved from 4.69261 to 4.68093, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 376ms/step - loss: 4.6048 - accuracy: 1.0000 - val_loss: 4.6809 - val_accuracy: 0.9608
# Epoch 264/300
# 7/7 [==============================] - ETA: 0s - loss: 4.6089 - accuracy: 0.9802
# Epoch 264: val_accuracy did not improve from 0.98039
#
# Epoch 264: val_loss improved from 4.68093 to 4.66827, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 418ms/step - loss: 4.6089 - accuracy: 0.9802 - val_loss: 4.6683 - val_accuracy: 0.9608
# Epoch 265/300
# 7/7 [==============================] - ETA: 0s - loss: 4.5853 - accuracy: 0.9950
# Epoch 265: val_accuracy did not improve from 0.98039
#
# Epoch 265: val_loss improved from 4.66827 to 4.65570, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 375ms/step - loss: 4.5853 - accuracy: 0.9950 - val_loss: 4.6557 - val_accuracy: 0.9608
# Epoch 266/300
# 7/7 [==============================] - ETA: 0s - loss: 4.5731 - accuracy: 0.9901
# Epoch 266: val_accuracy did not improve from 0.98039
#
# Epoch 266: val_loss improved from 4.65570 to 4.64278, saving model to Best-val_loss.h5
# 7/7 [==============================] - 4s 595ms/step - loss: 4.5731 - accuracy: 0.9901 - val_loss: 4.6428 - val_accuracy: 0.9608
# Epoch 267/300
# 7/7 [==============================] - ETA: 0s - loss: 4.5669 - accuracy: 0.9950
# Epoch 267: val_accuracy did not improve from 0.98039
#
# Epoch 267: val_loss improved from 4.64278 to 4.63038, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 370ms/step - loss: 4.5669 - accuracy: 0.9950 - val_loss: 4.6304 - val_accuracy: 0.9608
# Epoch 268/300
# 7/7 [==============================] - ETA: 0s - loss: 4.5750 - accuracy: 0.9851
# Epoch 268: val_accuracy did not improve from 0.98039
#
# Epoch 268: val_loss improved from 4.63038 to 4.61856, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 426ms/step - loss: 4.5750 - accuracy: 0.9851 - val_loss: 4.6186 - val_accuracy: 0.9608
# Epoch 269/300
# 7/7 [==============================] - ETA: 0s - loss: 4.5683 - accuracy: 0.9851
# Epoch 269: val_accuracy did not improve from 0.98039
#
# Epoch 269: val_loss improved from 4.61856 to 4.60645, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 445ms/step - loss: 4.5683 - accuracy: 0.9851 - val_loss: 4.6065 - val_accuracy: 0.9608
# Epoch 270/300
# 7/7 [==============================] - ETA: 0s - loss: 4.5255 - accuracy: 0.9851
# Epoch 270: val_accuracy did not improve from 0.98039
#
# Epoch 270: val_loss improved from 4.60645 to 4.59460, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 404ms/step - loss: 4.5255 - accuracy: 0.9851 - val_loss: 4.5946 - val_accuracy: 0.9608
# Epoch 271/300
# 7/7 [==============================] - ETA: 0s - loss: 4.5307 - accuracy: 0.9901
# Epoch 271: val_accuracy did not improve from 0.98039
#
# Epoch 271: val_loss improved from 4.59460 to 4.58273, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 392ms/step - loss: 4.5307 - accuracy: 0.9901 - val_loss: 4.5827 - val_accuracy: 0.9608
# Epoch 272/300
# 7/7 [==============================] - ETA: 0s - loss: 4.5080 - accuracy: 0.9950
# Epoch 272: val_accuracy did not improve from 0.98039
#
# Epoch 272: val_loss improved from 4.58273 to 4.57074, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 401ms/step - loss: 4.5080 - accuracy: 0.9950 - val_loss: 4.5707 - val_accuracy: 0.9608
# Epoch 273/300
# 7/7 [==============================] - ETA: 0s - loss: 4.4854 - accuracy: 0.9901
# Epoch 273: val_accuracy did not improve from 0.98039
#
# Epoch 273: val_loss improved from 4.57074 to 4.55939, saving model to Best-val_loss.h5
# 7/7 [==============================] - 4s 549ms/step - loss: 4.4854 - accuracy: 0.9901 - val_loss: 4.5594 - val_accuracy: 0.9608
# Epoch 274/300
# 7/7 [==============================] - ETA: 0s - loss: 4.4936 - accuracy: 0.9901
# Epoch 274: val_accuracy did not improve from 0.98039
#
# Epoch 274: val_loss improved from 4.55939 to 4.54822, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 380ms/step - loss: 4.4936 - accuracy: 0.9901 - val_loss: 4.5482 - val_accuracy: 0.9608
# Epoch 275/300
# 7/7 [==============================] - ETA: 0s - loss: 4.4698 - accuracy: 0.9901
# Epoch 275: val_accuracy did not improve from 0.98039
#
# Epoch 275: val_loss improved from 4.54822 to 4.53627, saving model to Best-val_loss.h5
# 7/7 [==============================] - 2s 359ms/step - loss: 4.4698 - accuracy: 0.9901 - val_loss: 4.5363 - val_accuracy: 0.9608
# Epoch 276/300
# 7/7 [==============================] - ETA: 0s - loss: 4.4524 - accuracy: 0.9950
# Epoch 276: val_accuracy did not improve from 0.98039
#
# Epoch 276: val_loss improved from 4.53627 to 4.52507, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 430ms/step - loss: 4.4524 - accuracy: 0.9950 - val_loss: 4.5251 - val_accuracy: 0.9608
# Epoch 277/300
# 7/7 [==============================] - ETA: 0s - loss: 4.4501 - accuracy: 0.9950
# Epoch 277: val_accuracy did not improve from 0.98039
#
# Epoch 277: val_loss improved from 4.52507 to 4.51339, saving model to Best-val_loss.h5
# 7/7 [==============================] - 6s 887ms/step - loss: 4.4501 - accuracy: 0.9950 - val_loss: 4.5134 - val_accuracy: 0.9608
# Epoch 278/300
# 7/7 [==============================] - ETA: 0s - loss: 4.4318 - accuracy: 0.9950
# Epoch 278: val_accuracy did not improve from 0.98039
#
# Epoch 278: val_loss improved from 4.51339 to 4.50272, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 376ms/step - loss: 4.4318 - accuracy: 0.9950 - val_loss: 4.5027 - val_accuracy: 0.9608
# Epoch 279/300
# 7/7 [==============================] - ETA: 0s - loss: 4.4126 - accuracy: 1.0000
# Epoch 279: val_accuracy did not improve from 0.98039
#
# Epoch 279: val_loss improved from 4.50272 to 4.49163, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 387ms/step - loss: 4.4126 - accuracy: 1.0000 - val_loss: 4.4916 - val_accuracy: 0.9608
# Epoch 280/300
# 7/7 [==============================] - ETA: 0s - loss: 4.4207 - accuracy: 0.9950
# Epoch 280: val_accuracy did not improve from 0.98039
#
# Epoch 280: val_loss improved from 4.49163 to 4.48039, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 403ms/step - loss: 4.4207 - accuracy: 0.9950 - val_loss: 4.4804 - val_accuracy: 0.9608
# Epoch 281/300
# 7/7 [==============================] - ETA: 0s - loss: 4.4253 - accuracy: 0.9752
# Epoch 281: val_accuracy did not improve from 0.98039
#
# Epoch 281: val_loss improved from 4.48039 to 4.46922, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 389ms/step - loss: 4.4253 - accuracy: 0.9752 - val_loss: 4.4692 - val_accuracy: 0.9608
# Epoch 282/300
# 7/7 [==============================] - ETA: 0s - loss: 4.3835 - accuracy: 0.9901
# Epoch 282: val_accuracy did not improve from 0.98039
#
# Epoch 282: val_loss improved from 4.46922 to 4.45758, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 433ms/step - loss: 4.3835 - accuracy: 0.9901 - val_loss: 4.4576 - val_accuracy: 0.9608
# Epoch 283/300
# 7/7 [==============================] - ETA: 0s - loss: 4.4105 - accuracy: 0.9802
# Epoch 283: val_accuracy did not improve from 0.98039
#
# Epoch 283: val_loss improved from 4.45758 to 4.44683, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 377ms/step - loss: 4.4105 - accuracy: 0.9802 - val_loss: 4.4468 - val_accuracy: 0.9608
# Epoch 284/300
# 7/7 [==============================] - ETA: 0s - loss: 4.3690 - accuracy: 0.9901
# Epoch 284: val_accuracy did not improve from 0.98039
#
# Epoch 284: val_loss improved from 4.44683 to 4.43667, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 420ms/step - loss: 4.3690 - accuracy: 0.9901 - val_loss: 4.4367 - val_accuracy: 0.9608
# Epoch 285/300
# 7/7 [==============================] - ETA: 0s - loss: 4.3686 - accuracy: 0.9901
# Epoch 285: val_accuracy did not improve from 0.98039
#
# Epoch 285: val_loss improved from 4.43667 to 4.42683, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 404ms/step - loss: 4.3686 - accuracy: 0.9901 - val_loss: 4.4268 - val_accuracy: 0.9608
# Epoch 286/300
# 7/7 [==============================] - ETA: 0s - loss: 4.3372 - accuracy: 0.9950
# Epoch 286: val_accuracy did not improve from 0.98039
#
# Epoch 286: val_loss improved from 4.42683 to 4.41670, saving model to Best-val_loss.h5
# 7/7 [==============================] - 4s 548ms/step - loss: 4.3372 - accuracy: 0.9950 - val_loss: 4.4167 - val_accuracy: 0.9608
# Epoch 287/300
# 7/7 [==============================] - ETA: 0s - loss: 4.3260 - accuracy: 1.0000
# Epoch 287: val_accuracy did not improve from 0.98039
#
# Epoch 287: val_loss improved from 4.41670 to 4.40494, saving model to Best-val_loss.h5
# 7/7 [==============================] - 4s 514ms/step - loss: 4.3260 - accuracy: 1.0000 - val_loss: 4.4049 - val_accuracy: 0.9608
# Epoch 288/300
# 7/7 [==============================] - ETA: 0s - loss: 4.3298 - accuracy: 0.9901
# Epoch 288: val_accuracy did not improve from 0.98039
#
# Epoch 288: val_loss improved from 4.40494 to 4.39377, saving model to Best-val_loss.h5
# 7/7 [==============================] - 2s 363ms/step - loss: 4.3298 - accuracy: 0.9901 - val_loss: 4.3938 - val_accuracy: 0.9608
# Epoch 289/300
# 7/7 [==============================] - ETA: 0s - loss: 4.3033 - accuracy: 1.0000
# Epoch 289: val_accuracy did not improve from 0.98039
#
# Epoch 289: val_loss improved from 4.39377 to 4.38278, saving model to Best-val_loss.h5
# 7/7 [==============================] - 2s 370ms/step - loss: 4.3033 - accuracy: 1.0000 - val_loss: 4.3828 - val_accuracy: 0.9608
# Epoch 290/300
# 7/7 [==============================] - ETA: 0s - loss: 4.3111 - accuracy: 0.9851
# Epoch 290: val_accuracy did not improve from 0.98039
#
# Epoch 290: val_loss improved from 4.38278 to 4.37172, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 378ms/step - loss: 4.3111 - accuracy: 0.9851 - val_loss: 4.3717 - val_accuracy: 0.9608
# Epoch 291/300
# 7/7 [==============================] - ETA: 0s - loss: 4.2899 - accuracy: 0.9901
# Epoch 291: val_accuracy did not improve from 0.98039
#
# Epoch 291: val_loss improved from 4.37172 to 4.36133, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 482ms/step - loss: 4.2899 - accuracy: 0.9901 - val_loss: 4.3613 - val_accuracy: 0.9608
# Epoch 292/300
# 7/7 [==============================] - ETA: 0s - loss: 4.2853 - accuracy: 0.9752
# Epoch 292: val_accuracy did not improve from 0.98039
#
# Epoch 292: val_loss improved from 4.36133 to 4.35050, saving model to Best-val_loss.h5
# 7/7 [==============================] - 2s 370ms/step - loss: 4.2853 - accuracy: 0.9752 - val_loss: 4.3505 - val_accuracy: 0.9608
# Epoch 293/300
# 7/7 [==============================] - ETA: 0s - loss: 4.2666 - accuracy: 0.9950
# Epoch 293: val_accuracy did not improve from 0.98039
#
# Epoch 293: val_loss improved from 4.35050 to 4.33934, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 415ms/step - loss: 4.2666 - accuracy: 0.9950 - val_loss: 4.3393 - val_accuracy: 0.9608
# Epoch 294/300
# 7/7 [==============================] - ETA: 0s - loss: 4.2565 - accuracy: 0.9950
# Epoch 294: val_accuracy did not improve from 0.98039
#
# Epoch 294: val_loss improved from 4.33934 to 4.32800, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 408ms/step - loss: 4.2565 - accuracy: 0.9950 - val_loss: 4.3280 - val_accuracy: 0.9608
# Epoch 295/300
# 7/7 [==============================] - ETA: 0s - loss: 4.2569 - accuracy: 0.9802
# Epoch 295: val_accuracy did not improve from 0.98039
#
# Epoch 295: val_loss improved from 4.32800 to 4.31735, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 405ms/step - loss: 4.2569 - accuracy: 0.9802 - val_loss: 4.3173 - val_accuracy: 0.9608
# Epoch 296/300
# 7/7 [==============================] - ETA: 0s - loss: 4.2241 - accuracy: 0.9950
# Epoch 296: val_accuracy did not improve from 0.98039
#
# Epoch 296: val_loss improved from 4.31735 to 4.30632, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 475ms/step - loss: 4.2241 - accuracy: 0.9950 - val_loss: 4.3063 - val_accuracy: 0.9608
# Epoch 297/300
# 7/7 [==============================] - ETA: 0s - loss: 4.2165 - accuracy: 0.9950
# Epoch 297: val_accuracy did not improve from 0.98039
#
# Epoch 297: val_loss improved from 4.30632 to 4.29554, saving model to Best-val_loss.h5
# 7/7 [==============================] - 2s 365ms/step - loss: 4.2165 - accuracy: 0.9950 - val_loss: 4.2955 - val_accuracy: 0.9608
# Epoch 298/300
# 7/7 [==============================] - ETA: 0s - loss: 4.2214 - accuracy: 0.9950
# Epoch 298: val_accuracy did not improve from 0.98039
#
# Epoch 298: val_loss improved from 4.29554 to 4.28412, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 396ms/step - loss: 4.2214 - accuracy: 0.9950 - val_loss: 4.2841 - val_accuracy: 0.9608
# Epoch 299/300
# 7/7 [==============================] - ETA: 0s - loss: 4.2002 - accuracy: 0.9901
# Epoch 299: val_accuracy did not improve from 0.98039
#
# Epoch 299: val_loss improved from 4.28412 to 4.27183, saving model to Best-val_loss.h5
# 7/7 [==============================] - 2s 370ms/step - loss: 4.2002 - accuracy: 0.9901 - val_loss: 4.2718 - val_accuracy: 0.9608
# Epoch 300/300
# 7/7 [==============================] - ETA: 0s - loss: 4.1899 - accuracy: 0.9901
# Epoch 300: val_accuracy did not improve from 0.98039
#
# Epoch 300: val_loss improved from 4.27183 to 4.26069, saving model to Best-val_loss.h5
# 7/7 [==============================] - 3s 499ms/step - loss: 4.1899 - accuracy: 0.9901 - val_loss: 4.2607 - val_accuracy: 0.9608

# %%
model.load_weights('Best-val_accuracy.h5')
#model = keras.models.load_model('Weights-038-val_loss-0.43673.h5')

# %%
train_score = model.evaluate(training_set)
#valid_score = model.evaluate(vald_set)
test_score = model.evaluate(test_set)

print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print('-' * 20)
#print("Validation Loss: ", valid_score[0])
#print("Validation Accuracy: ", valid_score[1])
print('-' * 20)
print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])
# Out:
# 7/7 [==============================] - 17s 421ms/step - loss: 0.1067 - accuracy: 0.9851
# 2/2 [==============================] - 2s 1s/step - loss: 0.0932 - accuracy: 1.0000
# Train Loss:  0.10673811286687851
# Train Accuracy:  0.9851484894752502
# --------------------
# --------------------
# Test Loss:  0.09316087514162064
# Test Accuracy:  1.0

# %%
train_score = model.evaluate(training_set)
#valid_score = model.evaluate(vald_set)
test_score = model.evaluate(test_set)

print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print('-' * 20)
#print("Validation Loss: ", valid_score[0])
#print("Validation Accuracy: ", valid_score[1])
print('-' * 20)
print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])
# Out:
# 7/7 [==============================] - 2s 184ms/step - loss: 6.6265 - accuracy: 1.0000
# 2/2 [==============================] - 0s 137ms/step - loss: 6.7520 - accuracy: 0.9804
# Train Loss:  6.626478672027588
# Train Accuracy:  1.0
# --------------------
# --------------------
# Test Loss:  6.752020835876465
# Test Accuracy:  0.9803921580314636

# %%
#model.save('2class_98.0.h5')

# %%
model = keras.models.load_model('2calss_lagre_dataset_99.1.h5')

# %%
img = tf.keras.utils.load_img(
    "0a0bc6879f5d5d14c4df229b64b801_big_gallery.jpeg",
    grayscale=False,
    color_mode='rgb',
    target_size=(224,224),
    interpolation='nearest',
    keep_aspect_ratio=False
    )
plt.imshow(img)
plt.axis('off')

# %%
img = np.array(img).reshape(-1, 224, 224, 3)
img.shape

# %%
y_pred = model.predict(img)
y_pred_labels = np.argmax(y_pred, axis=1)

# %%
result=['Astrocitoma T1',
 'Astrocitoma T1C+',
 'Astrocitoma T2',
 'Carcinoma T1',
 'Carcinoma T1C+',
 'Carcinoma T2',
 'Ependimoma T1',
 'Ependimoma T1C+',
 'Ependimoma T2',
 'Ganglioglioma T1',
 'Ganglioglioma T1C+',
 'Ganglioglioma T2',
 'Germinoma T1',
 'Germinoma T1C+',
 'Germinoma T2',
 'Glioblastoma T1',
 'Glioblastoma T1C+',
 'Glioblastoma T2',
 'Granuloma T1',
 'Granuloma T1C+',
 'Granuloma T2',
 'Meduloblastoma T1',
 'Meduloblastoma T1C+',
 'Meduloblastoma T2',
 'Meningioma T1',
 'Meningioma T1C+',
 'Meningioma T2',
 'Neurocitoma T1',
 'Neurocitoma T1C+',
 'Neurocitoma T2',
 'Oligodendroglioma T1',
 'Oligodendroglioma T1C+',
 'Oligodendroglioma T2',
 'Papiloma T1',
 'Papiloma T1C+',
 'Papiloma T2',
 'Schwannoma T1',
 'Schwannoma T1C+',
 'Schwannoma T2',
 'Tuberculoma T1',
 'Tuberculoma T1C+',
 'Tuberculoma T2',
 '_NORMAL T1',
 '_NORMAL T2']

# %%
result[y_pred_labels[0]]

# %%
plt.figure(figsize= (20, 8))
plt.style.use('fivethirtyeight')

plt.subplot(1, 2, 1)
plt.plot(res.history['loss'], 'r', label= 'Training loss')
plt.plot(res.history['val_loss'], 'b', label= 'Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(res.history['accuracy'], 'r', label= 'Training Accuracy')
plt.plot(res.history['val_accuracy'], 'b', label= 'Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout
plt.savefig('EfficientNetB5_2calss.png')
plt.show()
